# %%
#Import necessary libraries:

import numpy as np
import pandas as pd
import mlxtend

# %%
from mlxtend.frequent_patterns import association_rules, apriori

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Read the data:
market=pd.read_excel("OnlineClothing.xlsx",sheet_name="Data")

# %%
market
# Out:
#      OrderID    CustomerID   PurchaseDate (yy-mm-dd)  ProductID   \
# 0        1001           101               2023-06-27         P01
# 1        1001           101               2023-06-27         P02
# 2        1002           102               2023-07-28         P07
# 3        1003           103               2023-07-29         P03
# 4        1003           103               2023-07-29         P04
# 5        1004           104               2023-08-31         P05
# 6        1004           104               2023-08-31         P06
# 7        1005           105               2023-09-01         P03
# 8        1005           105               2023-09-01         P04
# 9        1006           105               2023-09-02         P07
# 10       1007           104               2023-09-07         P05
# 11       1007           104               2023-09-07         P06
# 12       1008           106               2023-10-05         P15
# 13       1009           107               2023-10-16         P14
# 14       1010           108               2023-10-26         P15
# 15       1011           103               2023-10-27         P03
# 16       1011           103               2023-07-29         P04
# 17       1012           109               2023-10-27         P14
# 18       1013           110               2023-10-28         P15
# 19       1014           111               2023-10-29         P14
# 20       1015           101               2023-11-01         P10
# 21       1016           103               2023-11-02         P11
# 22       1016           103               2023-11-02         P12
# 23       1017           103               2023-11-04         P13
# 24       1018           101               2023-11-05         P10
# 25       1019           105               2023-11-06         P11
# 26       1019           105               2023-11-06         P12
# 27       1020           106               2023-12-10         P05
# 28       1020           106               2023-12-10         P06
# 29       1021           107               2024-01-01         P11
# 30       1021           107               2024-01-01         P12
# 31       1022           101               2024-02-01         P09
# 32       1022           101               2024-02-01         P02
# 33       1023           111               2024-02-03         P09
# 34       1023           111               2024-02-03         P02
#
#                 Product   Quantity    UnitPrice
# 0            Summer Cap           2          100
# 1            Sunglasses           1           50
# 2                 Kurta           1          150
# 3   Half Sleeve T-shirt           1          200
# 4                 Capri           2          350
# 5                 Saree           1          400
# 6              Earrings           1           30
# 7   Half Sleeve T-shirt           1          200
# 8                 Capri           2          350
# 9                 Kurta           2          150
# 10                Saree           2          400
# 11             Earrings           1           30
# 12              Lahenga           1         4000
# 13             Sherwani           1         2000
# 14              Lahenga           1         4000
# 15  Half Sleeve T-shirt           1          200
# 16                Capri           2          350
# 17             Sherwani           1         2000
# 18              Lahenga           1         4000
# 19             Sherwani           1         2000
# 20           Sweatshirt           2          250
# 21  Long Sleeve T-shirt           1          300
# 22                Jeans           1          600
# 23           Thermocoat           1          270
# 24           Sweatshirt           2          250
# 25  Long Sleeve T-shirt           1          300
# 26                Jeans           1          600
# 27                Saree           1          400
# 28             Earrings           1           30
# 29  Long Sleeve T-shirt           1          300
# 30                Jeans           1          600
# 31           Winter Cap           1          150
# 32           Sunglasses           1           50
# 33           Winter Cap           1          150
# 34           Sunglasses           1           50

# %%
#checking for missing values:

market.isnull().sum()
# Out:
#  OrderID                    0
#  CustomerID                 0
#  PurchaseDate (yy-mm-dd)    0
#  ProductID                  0
# Product                     0
#  Quantity                   0
#  UnitPrice                  0
# dtype: int64

# %% [markdown]
# So, there is no missing value the the dataset.

# %%
#checking for duplicate rows:
market[market.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ OrderID ,  CustomerID ,  PurchaseDate (yy-mm-dd),  ProductID , Product,  Quantity ,  UnitPrice ]
# Index: []

# %% [markdown]
# So, there is no duplicate entry.

# %%
market.columns
# Out:
# Index([' OrderID ', ' CustomerID ', ' PurchaseDate (yy-mm-dd)', ' ProductID ',
#        'Product', ' Quantity ', ' UnitPrice '],
#       dtype='object')

# %%
# transforming the data for applying ariori alogorithm:

transaction_data = market[[" OrderID ","Product"]].copy()

# %%
# One-hot encoding the transaction data
encoded_transaction_data = transaction_data.groupby([' OrderID ', 'Product']).size().unstack(fill_value=0)
encoded_transaction_data = encoded_transaction_data.applymap(lambda x: 1 if x > 0 else 0)

# %%
encoded_transaction_data
# Out:
# Product    Capri  Earrings  Half Sleeve T-shirt  Jeans  Kurta  Lahenga  \
#  OrderID
